# %%
# Imports 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#warnings
import warnings
warnings.simplefilter(action="ignore")

# %%
raw_data = pd.read_csv('housing_train_data.txt', sep=",")
raw_data
# Out:
#        Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 0            2072    -119.84     36.77                 6.0       1853.0
# 1           10600    -117.80     33.68                 8.0       2032.0
# 2            2494    -120.19     36.60                25.0        875.0
# 3            4284    -118.32     34.10                31.0        622.0
# 4           16541    -121.23     37.79                21.0       1922.0
# ...           ...        ...       ...                 ...          ...
# 16507        1099    -121.90     39.59                20.0       1465.0
# 16508       18898    -122.25     38.11                49.0       2365.0
# 16509       11798    -121.22     38.92                19.0       2531.0
# 16510        6637    -118.14     34.16                39.0       2776.0
# 16511        2575    -124.13     40.80                31.0       2152.0
#
#        total_bedrooms  population  households  median_income  \
# ...

# %%
#Checking for missing data
raw_data.isnull().sum()
# Out:
# Unnamed: 0              0
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        176
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
raw_data.corr()
# Out:
#                     Unnamed: 0  longitude  latitude  housing_median_age  \
# Unnamed: 0            1.000000  -0.112693  0.082515           -0.180942
# longitude            -0.112693   1.000000 -0.924753           -0.109873
# latitude              0.082515  -0.924753  1.000000            0.010653
# housing_median_age   -0.180942  -0.109873  0.010653            1.000000
# total_rooms           0.058565   0.044776 -0.035012           -0.362083
# total_bedrooms        0.029524   0.069623 -0.065210           -0.324779
# population            0.022067   0.099824 -0.106416           -0.295541
# households            0.027158   0.055629 -0.068901           -0.307466
# median_income         0.067317  -0.019501 -0.076643           -0.113804
# median_house_value    0.065435  -0.046754 -0.143970            0.108626
#
#                     total_rooms  total_bedrooms  population  households  \
# Unnamed: 0             0.058565        0.029524    0.022067    0.027158
# ...

# %%
g =sns.scatterplot(x="latitude", y="longitude",
              hue="median_house_value",
              data=raw_data);
g.set();

# %% [markdown]
# ### Outliers

# %%
#Checking for outliers
raw_data.describe()
# Out:
#          Unnamed: 0     longitude      latitude  housing_median_age  \
# count  16512.000000  16512.000000  16512.000000        16512.000000
# mean   10295.498789   -119.564046     35.626523           28.624516
# std     5941.973488      2.005033      2.139150           12.597980
# min        0.000000   -124.350000     32.540000            1.000000
# 25%     5178.750000   -121.790000     33.930000           18.000000
# 50%    10263.500000   -118.490000     34.250000           29.000000
# 75%    15438.250000   -118.010000     37.710000           37.000000
# max    20639.000000   -114.310000     41.950000           52.000000
#
#         total_rooms  total_bedrooms    population    households  \
# count  16512.000000    16336.000000  16512.000000  16512.000000
# mean    2644.170603      539.319540   1435.017260    501.135962
# std     2213.946369      425.207704   1158.151967    385.650673
# min        6.000000        2.000000      3.000000      2.000000
# ...

# %%
#Box plot have a visualisation of the table above
raw_data.plot(kind='box', subplots=True, layout=(4, 4), figsize = (10, 10));

# %%
fig, axs = plt.subplots(figsize=(8, 8)) #size plot

sns.histplot(data= raw_data, x= "median_house_value",
          kde=True)
plt.xticks(fontsize=12, rotation=30)
plt.show()

# %% [markdown]
# There is no goods above 500K, they all have been rounded to this value.

# %%
raw_data[raw_data['median_house_value']==500001]
# Out:
#        Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 6            5438    -118.43     34.01                31.0       2526.0
# 10           5305    -118.46     34.07                42.0       2564.0
# 37           4355    -118.39     34.09                41.0        730.0
# 45          18285    -122.10     37.37                37.0       2511.0
# 57           8804    -118.42     33.75                22.0      17591.0
# ...           ...        ...       ...                 ...          ...
# 16334       18063    -122.01     37.26                14.0       2561.0
# 16366       12069    -117.55     33.83                 6.0        502.0
# 16370        4115    -118.42     34.14                27.0       3990.0
# 16414        4700    -118.38     34.07                21.0       3653.0
# 16437        4624    -118.32     34.06                52.0        983.0
#
#        total_bedrooms  population  households  median_income  \
# ...

# %% [markdown]
# 763 goods have their prices set to 500 001$,
# is this going to influence our prediction?
#
# I separated them to see how it can influence the model

# %%
out_data = raw_data[raw_data['median_house_value']==500001]

# %%
pd.get_dummie
# Out:
#                     Unnamed: 0  longitude  latitude  housing_median_age  \
# Unnamed: 0            1.000000  -0.564208  0.520333           -0.040935
# longitude            -0.564208   1.000000 -0.991505           -0.197301
# latitude              0.520333  -0.991505  1.000000            0.204976
# housing_median_age   -0.040935  -0.197301  0.204976            1.000000
# total_rooms          -0.141348   0.065119 -0.068647           -0.272303
# total_bedrooms       -0.136816   0.073356 -0.078721           -0.204153
# population           -0.136652   0.052341 -0.056354           -0.262530
# households           -0.141672   0.054957 -0.060127           -0.192092
# median_income        -0.053281  -0.046523  0.050580           -0.077508
# median_house_value         NaN        NaN       NaN                 NaN
#
#                     total_rooms  total_bedrooms  population  households  \
# Unnamed: 0            -0.141348       -0.136816   -0.136652   -0.141672
# ...

# %%
out_data.describe()
# Out:
#          Unnamed: 0   longitude    latitude  housing_median_age   total_rooms  \
# count    763.000000  763.000000  763.000000          763.000000    763.000000
# mean   10788.235911 -119.678283   35.205740           33.778506   2996.876802
# std     5291.741364    1.940548    1.773241           13.022370   2167.394173
# min       89.000000 -122.640000   32.680000            2.000000     30.000000
# 25%     5488.500000 -122.110000   33.970000           25.000000   1675.000000
# 50%     9380.000000 -118.470000   34.120000           34.000000   2511.000000
# 75%    16123.500000 -118.330000   37.390000           44.000000   3556.500000
# max    20443.000000 -116.430000   37.980000           52.000000  17591.000000
#
#        total_bedrooms   population   households  median_income  \
# count      757.000000   763.000000   763.000000     763.000000
# mean       501.249670  1123.853211   465.941022       7.873707
# std        371.644372   810.936630   337.318934       3.195990
# ...

# %%
g =sns.scatterplot(x="latitude", y="longitude",
              hue="median_house_value",
              data=out_data);

# %%
no_out_data = raw_data[raw_data['median_house_value'] < 500001]

# %%
no_out_data
# Out:
#        Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 0            2072    -119.84     36.77                 6.0       1853.0
# 1           10600    -117.80     33.68                 8.0       2032.0
# 2            2494    -120.19     36.60                25.0        875.0
# 3            4284    -118.32     34.10                31.0        622.0
# 4           16541    -121.23     37.79                21.0       1922.0
# ...           ...        ...       ...                 ...          ...
# 16507        1099    -121.90     39.59                20.0       1465.0
# 16508       18898    -122.25     38.11                49.0       2365.0
# 16509       11798    -121.22     38.92                19.0       2531.0
# 16510        6637    -118.14     34.16                39.0       2776.0
# 16511        2575    -124.13     40.80                31.0       2152.0
#
#        total_bedrooms  population  households  median_income  \
# ...

# %%
out_data
# Out:
#        Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 6            5438    -118.43     34.01                31.0       2526.0
# 10           5305    -118.46     34.07                42.0       2564.0
# 37           4355    -118.39     34.09                41.0        730.0
# 45          18285    -122.10     37.37                37.0       2511.0
# 57           8804    -118.42     33.75                22.0      17591.0
# ...           ...        ...       ...                 ...          ...
# 16334       18063    -122.01     37.26                14.0       2561.0
# 16366       12069    -117.55     33.83                 6.0        502.0
# 16370        4115    -118.42     34.14                27.0       3990.0
# 16414        4700    -118.38     34.07                21.0       3653.0
# 16437        4624    -118.32     34.06                52.0        983.0
#
#        total_bedrooms  population  households  median_income  \
# ...

# %%
sns.pairplot(out_data)

# %%
corr = out_data.corr()

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(corr, annot=True)
plt.show()

# %%
out_data.isnull().sum()
# Out:
# Unnamed: 0            0
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        6
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
out_data.describe()
# Out:
#          Unnamed: 0   longitude    latitude  housing_median_age   total_rooms  \
# count    763.000000  763.000000  763.000000          763.000000    763.000000
# mean   10788.235911 -119.678283   35.205740           33.778506   2996.876802
# std     5291.741364    1.940548    1.773241           13.022370   2167.394173
# min       89.000000 -122.640000   32.680000            2.000000     30.000000
# 25%     5488.500000 -122.110000   33.970000           25.000000   1675.000000
# 50%     9380.000000 -118.470000   34.120000           34.000000   2511.000000
# 75%    16123.500000 -118.330000   37.390000           44.000000   3556.500000
# max    20443.000000 -116.430000   37.980000           52.000000  17591.000000
#
#        total_bedrooms   population   households  median_income  \
# count      757.000000   763.000000   763.000000     763.000000
# mean       501.249670  1123.853211   465.941022       7.873707
# std        371.644372   810.936630   337.318934       3.195990
# ...

# %%
out_data.plot(kind='box', subplots=True, layout=(4, 4), figsize = (10, 10));
